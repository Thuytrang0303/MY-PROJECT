# %% [markdown]
# <a href="https://colab.research.google.com/github/Thuytrang0303/MY-PROJECT/blob/main/Sentiment_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import data from Mongo DB

# %%
# !pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 15.9 MB/s eta 0:00:00
# ...

# %%
import pymongo
from pymongo import MongoClient

# %%
CONNECTION_STRING = "mongodb+srv://longth:asdQWE123@cluster0.tehe2.azure.mongodb.net/?retryWrites=true&w=majority"

# %%
client = MongoClient(CONNECTION_STRING)

# %%
db = client['Data_Engineer']

# %%
collection = db["Comments"]

# %%
cursor = collection.find()

# %%
list_cur = list(cursor)

# %%
import pandas as pd
# biến đổi dữ liệu thành dạng dataframe
comments_df = pd.DataFrame(list_cur)

# %%
comments_df
# Out:
#                              _id  ranking  layer   user_id  like  \
# 0       555466761a77ce5d65ea062a        0      0        12     1
# 1       555457bf1a77ce5d65ea0617        0      0       130     5
# 2       555413001a77ce5d65ea0609        0      0    527201     0
# 3       555357f71a77ce5d65ea0606        0      0    424467     1
# 4       555491181a77ce5d65ea0636        0      0       805    12
# ...                          ...      ...    ...       ...   ...
# 885164  627543d15e052026df2928c6        0      0  14734162     0
# 885165  6136ee5e5e0520b679234d52        0      0  11069002     0
# 885166  627a3dc95e052026df2928c9        0      0  19094650     0
# 885167  627e52f45e052026df2928ce        0      0  19094650     0
# 885168  628e1dc35e052026df2928d6        0      0  19094650     0
#
#                         user_email comment_on              ip  \
# 0            hoaianh2210@gmail.com      event            null
# ...

# %%
comments_df.to_csv('comments_df.csv')

# %% [markdown]
# Clean Data

# %%
df = comments_df[["_id", "user_id", "comment_on","ip", "object_id", "content", "timestamp", "device"]]

# %%
df
# Out:
#                              _id   user_id comment_on              ip  \
# 0       555466761a77ce5d65ea062a        12      event            null
# 1       555457bf1a77ce5d65ea0617       130      event            null
# 2       555413001a77ce5d65ea0609    527201        vod    42.116.8.164
# 3       555357f71a77ce5d65ea0606    424467        vod            null
# 4       555491181a77ce5d65ea0636       805        vod   42.117.66.148
# ...                          ...       ...        ...             ...
# 885164  627543d15e052026df2928c6  14734162             171.248.252.59
# 885165  6136ee5e5e0520b679234d52  11069002             115.76.163.113
# 885166  627a3dc95e052026df2928c9  19094650             171.251.235.36
# 885167  627e52f45e052026df2928ce  19094650             171.251.235.47
# 885168  628e1dc35e052026df2928d6  19094650             171.251.234.77
#
#                        object_id  \
# 0       552b2f0817dc135c89d7d6a2
# 1       552b2f0817dc135c89d7d6a2
# ...

# %%
print(df.dtypes)
# Out:
# _id           object
# user_id        int64
# comment_on    object
# ip            object
# object_id     object
# content       object
# timestamp      int64
# device        object
# dtype: object

# %%
from datetime import datetime

# %%
import pandas as pd
df['datetime'] = pd.to_datetime(df['timestamp'], unit='s')
# Out:
# <ipython-input-34-8b67ec8f4ca9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['datetime'] = pd.to_datetime(df['timestamp'], unit='s')

# %%
df["timestamp"] = pd.to_datetime(df["timestamp"], unit='s')
# Out:
# <ipython-input-35-4b9db6b1d8b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["timestamp"] = pd.to_datetime(df["timestamp"], unit='s')

# %%
df['date']= df['datetime'].dt.date
# Out:
# <ipython-input-36-48cdeb60e4f4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']= df['datetime'].dt.date

# %%
df['hour']= df['datetime'].dt.hour
# Out:
# <ipython-input-37-1a3fbec7d2e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['hour']= df['datetime'].dt.hour

# %%
df
# Out:
#                              _id   user_id comment_on              ip  \
# 0       555466761a77ce5d65ea062a        12      event            null
# 1       555457bf1a77ce5d65ea0617       130      event            null
# 2       555413001a77ce5d65ea0609    527201        vod    42.116.8.164
# 3       555357f71a77ce5d65ea0606    424467        vod            null
# 4       555491181a77ce5d65ea0636       805        vod   42.117.66.148
# ...                          ...       ...        ...             ...
# 885164  627543d15e052026df2928c6  14734162             171.248.252.59
# 885165  6136ee5e5e0520b679234d52  11069002             115.76.163.113
# 885166  627a3dc95e052026df2928c9  19094650             171.251.235.36
# 885167  627e52f45e052026df2928ce  19094650             171.251.235.47
# 885168  628e1dc35e052026df2928d6  19094650             171.251.234.77
#
#                        object_id  \
# 0       552b2f0817dc135c89d7d6a2
# 1       552b2f0817dc135c89d7d6a2
# ...

# %% [markdown]
# Using Pre-trained PhoBERT model

# %%
# !pip install transformers

# %%
import numpy as np
import pandas as pd
import torch
from transformers import AutoModel, AutoTokenizer, RobertaForSequenceClassification

# %%
import requests

# Tăng thời gian timeout lên 30 giây
response = requests.get('https://huggingface.co', timeout=30)
# load pre trained model
model = RobertaForSequenceClassification.from_pretrained("wonrax/phobert-base-vietnamese-sentiment")

# load Tokenizer từ model (dùng để tách từ trong câu)
tokenizer = AutoTokenizer.from_pretrained("wonrax/phobert-base-vietnamese-sentiment", use_fast=False)

# %%
# test câu
sentence = 'chương trình hay quá'

# tách câu thành list từng từ
input_ids = torch.tensor([tokenizer.encode(sentence)])

with torch.no_grad():
    out = model(input_ids)
    # predict output bằng pretrained model
    out = pd.Series(out.logits.softmax(dim=-1).tolist()[0], index= ['NEG', 'POS', 'NEU'])
    print(out)
# Out:
# NEG    0.017476
# POS    0.703765
# NEU    0.278760
# dtype: float64

# %%
# hàm apply để đánh giá từng comment; 0 là tiêu cực, 1 là tích cực, 2 là trung tính hoặc ko thể xác định
def sentiment(sentence):
  try:
    input_ids = torch.tensor([tokenizer.encode(sentence)])
  except:
    return 2

  if input_ids.shape[1] > tokenizer.model_max_length:
    return 2

  with torch.no_grad():
      out = model(input_ids)
      return np.argmax(out.logits.softmax(dim=-1).tolist()[0])

# %%
df_1000 = df.head(1000)

# %%
df_1000
# Out:
#                           _id  user_id comment_on             ip  \
# 0    555466761a77ce5d65ea062a       12      event           null
# 1    555457bf1a77ce5d65ea0617      130      event           null
# 2    555413001a77ce5d65ea0609   527201        vod   42.116.8.164
# 3    555357f71a77ce5d65ea0606   424467        vod           null
# 4    555491181a77ce5d65ea0636      805        vod  42.117.66.148
# ..                        ...      ...        ...            ...
# 995  556211db1a77ce110a495da4   532136        vod  118.68.79.240
# 996  55628bdc1a77ce110a495db6   372844        vod           null
# 997  5562cd4a1a77ce110a495dcc   132963        vod   42.116.8.164
# 998  5562d2351a77ce110a495dd0   549986        vod           null
# 999  5562dd051a77ce110a495dda   540287        vod           null
#
#                     object_id  \
# 0    552b2f0817dc135c89d7d6a2
# 1    552b2f0817dc135c89d7d6a2
# 2    5453639f17dc1371f538a4cd
# 3    551a43b417dc135c58f3c691
# ...

# %%
import time
start_time = time.time()
# test 10000 first comments
test = df[:10000]
test['sentiment'] = test['content'].apply(sentiment)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (513 > 256). Running this sequence through the model will result in indexing errors
# --- 914.1056776046753 seconds ---
# <ipython-input-47-602fdc848a76>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['sentiment'] = test['content'].apply(sentiment)

# %%
data_10000=test[['user_id','ip','comment_on','content','sentiment', 'date', 'hour']]

# %%
# !pip install requests

# %%
import requests

# %%
def get_location(ip):
    try:
        response = requests.get(f"https://ipinfo.io/{ip}/json")
        data = response.json()
        return data.get("city", "N/A")
    except Exception as e:
        return None

# %%
import time
start_time = time.time()
data_10000['Tỉnh/Thành'] = data_10000['ip'].apply(get_location)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 713.6315977573395 seconds ---
# <ipython-input-56-abd6343ee6c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_10000['Tỉnh/Thành'] = data_10000['ip'].apply(get_location)

# %%
data_10000=data_10000[["user_id","comment_on","content","sentiment","date","hour","Tỉnh/Thành"]]

# %%
data_10000
# Out:
#       user_id comment_on                                            content  \
# 0          12      event  Chương trình \ Tuyệt cú mèo\ luôn, chờ lâu rồi...
# 1         130      event  Chờ đợi chương trình này đã lâu! Hẹn mọi người...
# 2      527201        vod                                        comment cai
# 3      424467        vod  lồng tiếng mà như tập đọc, nghe không nuốt nổi...
# 4         805        vod                                   Phim rất hay ;)
# ...       ...        ...                                                ...
# 9995   586933        vod                            Khúc cuối bị gì vậy =.=
# 9996   441175      event                         hôm nay ko to seagame nhỉ
# 9997   579180      event  năm nào cũng thua..rồi nói đã cố gắng hết sức....
# 9998   564474      event  bong đa VIÊT NAM con phai hoc tâp cai ban linh...
# 9999   587719        vod           toan bi dung hinh nhung ma hay tuyet voi
#
#       sentiment        date  hour Tỉnh/Thành
# ...

# %%
data_10000.to_csv('data_10000.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
